# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachanavk/Machine-Learning-/blob/main/SUVprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Step 1: Data Loading**

# %%
dataset = pd.read_csv('/content/sample_data/suv_data.csv')
print(dataset.head())
print(dataset.shape)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# (400, 5)

# %% [markdown]
# **Step 2: Data Analysis**

# %%
sns.countplot(x='Purchased',data=dataset)
# Out:
# <Axes: xlabel='Purchased', ylabel='count'>

# %%
sns.countplot(x='Purchased',hue='Gender',data=dataset)
# Out:
# <Axes: xlabel='Purchased', ylabel='count'>

# %%
dataset['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset['EstimatedSalary'].plot.hist(color='green')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Step 3: Data Wrangling**

# %%
dataset.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
dataset.drop(['User ID','Gender'],axis = 1,inplace=True)
dataset.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# **Step 4: Training and testing the data**

# %%
X = dataset.drop('Purchased',axis =1)
Y = dataset['Purchased']
print(X.shape)
print(Y.shape)
# Out:
# (400, 2)
# (400,)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
lg=LogisticRegression()
lg.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(xtest)

# %%
accuracy_score(ytest,y_pred)*100
# Out:
# 86.66666666666667
